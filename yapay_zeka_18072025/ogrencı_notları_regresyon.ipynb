# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Yapay Zeka Atölye/yapay_zeka_17072025/ogrenci_notlari.csv")
df
# Out:
#     ogrenci_id    isim       ders  vize  final  devamsizlik
# 0            1  Zeynep  Matematik   NaN   31.0            7
# 1            2  Zeynep   Biyoloji  47.0   37.0            8
# 2            3   Fatma  Matematik  88.0    NaN            9
# 3            4    Ayşe      Fizik  96.0   49.0            4
# 4            5  Mehmet      Fizik  75.0   93.0            4
# ..         ...     ...        ...   ...    ...          ...
# 95          96  Mehmet  Matematik  37.0   33.0            1
# 96          97    Elif   Biyoloji  91.0   79.0            1
# 97          98  Mehmet   Biyoloji  57.0   63.0            6
# 98          99    Ayşe      Kimya  95.0   64.0            6
# 99         100     Ali      Fizik  46.0   93.0            4
#
# [100 rows x 6 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ogrenci_id   100 non-null    int64
#  1   isim         100 non-null    object
#  2   ders         100 non-null    object
#  3   vize         97 non-null     float64
#  4   final        93 non-null     float64
#  5   devamsizlik  100 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB
# None

# %%
df["vize"] = df["vize"].fillna(df["vize"].mean())
df["final"] = df["final"].fillna(df["vize"].mean())

# %%
df["basarı_notu"] = df['vize']*0.4 + df["final"]*0.6

# %%
df
# Out:
#     ogrenci_id    isim       ders       vize      final  devamsizlik  \
# 0            1  Zeynep  Matematik  60.896907  31.000000            7
# 1            2  Zeynep   Biyoloji  47.000000  37.000000            8
# 2            3   Fatma  Matematik  88.000000  60.896907            9
# 3            4    Ayşe      Fizik  96.000000  49.000000            4
# 4            5  Mehmet      Fizik  75.000000  93.000000            4
# ..         ...     ...        ...        ...        ...          ...
# 95          96  Mehmet  Matematik  37.000000  33.000000            1
# 96          97    Elif   Biyoloji  91.000000  79.000000            1
# 97          98  Mehmet   Biyoloji  57.000000  63.000000            6
# 98          99    Ayşe      Kimya  95.000000  64.000000            6
# 99         100     Ali      Fizik  46.000000  93.000000            4
#
#     basarı_notu
# 0     42.958763
# 1     41.000000
# 2     71.738144
# 3     67.800000
# 4     85.800000
# ..          ...
# ...

# %%
df["durum"] = df["basarı_notu"].apply(lambda x: "geçti" if x >= 50 else "kaldı")
df
# Out:
#     ogrenci_id    isim       ders       vize      final  devamsizlik  \
# 0            1  Zeynep  Matematik  60.896907  31.000000            7
# 1            2  Zeynep   Biyoloji  47.000000  37.000000            8
# 2            3   Fatma  Matematik  88.000000  60.896907            9
# 3            4    Ayşe      Fizik  96.000000  49.000000            4
# 4            5  Mehmet      Fizik  75.000000  93.000000            4
# ..         ...     ...        ...        ...        ...          ...
# 95          96  Mehmet  Matematik  37.000000  33.000000            1
# 96          97    Elif   Biyoloji  91.000000  79.000000            1
# 97          98  Mehmet   Biyoloji  57.000000  63.000000            6
# 98          99    Ayşe      Kimya  95.000000  64.000000            6
# 99         100     Ali      Fizik  46.000000  93.000000            4
#
#     basarı_notu  durum
# 0     42.958763  kaldı
# 1     41.000000  kaldı
# 2     71.738144  geçti
# 3     67.800000  geçti
# ...

# %%
df_table = df.drop(columns=["ogrenci_id","isim","vize","final","basarı_notu"],axis=1)

# %%
df_table
# Out:
#          ders  devamsizlik  durum
# 0   Matematik            7  kaldı
# 1    Biyoloji            8  kaldı
# 2   Matematik            9  geçti
# 3       Fizik            4  geçti
# 4       Fizik            4  geçti
# ..        ...          ...    ...
# 95  Matematik            1  kaldı
# 96   Biyoloji            1  geçti
# 97   Biyoloji            6  geçti
# 98      Kimya            6  geçti
# 99      Fizik            4  geçti
#
# [100 rows x 3 columns]

# %%
print(df_table.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ders         100 non-null    object
#  1   devamsizlik  100 non-null    int64
#  2   durum        100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB
# None

# %%
df_table["durum"].value_counts()
# Out:
# durum
# geçti    83
# kaldı    17
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_table["durum"] = le.fit_transform(df_table["durum"])
df_table["ders"] = le.fit_transform(df_table["ders"])

# %%
df_table
# Out:
#     ders  devamsizlik  durum
# 0      3            7      1
# 1      0            8      1
# 2      3            9      0
# 3      1            4      0
# 4      1            4      0
# ..   ...          ...    ...
# 95     3            1      1
# 96     0            1      0
# 97     0            6      0
# 98     2            6      0
# 99     1            4      0
#
# [100 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X = df_table.drop("durum",axis=1)
y = df_table["durum"]

X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
X_train
# Out:
#     ders  devamsizlik
# 58     1            0
# 18     4            0
# 20     4            0
# 64     0            4
# 32     3            4
# ..   ...          ...
# 15     4            9
# 67     2            3
# 70     1            4
# 24     1            4
# 11     1            1
#
# [80 rows x 2 columns]

# %%
y_train
# Out:
# 58    0
# 18    0
# 20    0
# 64    0
# 32    0
#      ..
# 15    0
# 67    0
# 70    0
# 24    0
# 11    0
# Name: durum, Length: 80, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
for gerçek, tahmin in zip(y_test[:10], y_pred[:10]):
    print(f"Gerçek: {gerçek}, Tahmin: {tahmin}")
# Out:
# Gerçek: 0, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 1, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 1, Tahmin: 0
# Gerçek: 0, Tahmin: 0
# Gerçek: 0, Tahmin: 0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, zero_division=0)
recall = recall_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred, zero_division=0)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred, zero_division=0)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n"), class_report
# Out:
# Accuracy: 0.85
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  0]]
# Classification Report:
# (None,
#  '              precision    recall  f1-score   support\n\n           0       0.85      1.00      0.92        17\n           1       0.00      0.00      0.00         3\n\n    accuracy                           0.85        20\n   macro avg       0.42      0.50      0.46        20\nweighted avg       0.72      0.85      0.78        20\n')
